# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Kategorien vorbereiten
#
# Hier geht es darum, die Kategorien so zu bearbeiten, dass sie als Zahlen verarbeitet werden können.

# %%
df_ex = sns.load_dataset('exercise')
df_ex.head(10)
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest
# 5           5   2  low fat     93  30 min  rest
# 6           6   3  low fat     97   1 min  rest
# 7           7   3  low fat     97  15 min  rest
# 8           8   3  low fat     94  30 min  rest
# 9           9   4  low fat     80   1 min  rest

# %%
df_ex['diet'].value_counts()
# Out:
# diet
# no fat     45
# low fat    45
# Name: count, dtype: int64

# %%
df_ex['time'].value_counts()
# Out:
# 1 min     30
# 15 min    30
# 30 min    30
# Name: time, dtype: int64

# %%
df_ex['kind'].value_counts()
# Out:
# rest       30
# walking    30
# running    30
# Name: kind, dtype: int64

# %% [markdown]
# ### Ansatz 1: Werte ersetzen

# %%
df_ex_replace = df_ex.replace({
    "diet": {
        "no fat": 0,
        "low fat": 1
    },
    "time": {
        "1 min": 1,
        "15 min": 15,
        "30 min": 30
    }
})
df_ex_replace
# Out:
#     Unnamed: 0  id  diet  pulse  time     kind
# 0            0   1     1     85     1     rest
# 1            1   1     1     85    15     rest
# 2            2   1     1     88    30     rest
# 3            3   2     1     90     1     rest
# 4            4   2     1     92    15     rest
# ..         ...  ..   ...    ...   ...      ...
# 85          85  29     0    135    15  running
# 86          86  29     0    130    30  running
# 87          87  30     0     99     1  running
# 88          88  30     0    111    15  running
# 89          89  30     0    150    30  running
#
# [90 rows x 6 columns]

# %% [markdown]
# ### Ansatz 2: `Categorical`
#
# `Categorical` nimmt verschiedene Kategorien und weist ihnen eine Zahl zu.

# %%
df_ex_cat = df_ex.copy()
df_ex_cat['diet'] = df_ex_cat['diet'].astype('category')
df_ex_cat['time'] = df_ex_cat['time'].astype('category')
df_ex_cat[['diet', 'time']].dtypes
# Out:
# diet    category
# time    category
# dtype: object

# %%
df_ex_cat['diet_encoded'] = df_ex_cat['diet'].cat.codes
df_ex_cat['time_encoded'] = df_ex_cat['time'].cat.codes
df_ex_cat
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind  diet_encoded  \
# 0            0   1  low fat     85   1 min     rest             1
# 1            1   1  low fat     85  15 min     rest             1
# 2            2   1  low fat     88  30 min     rest             1
# 3            3   2  low fat     90   1 min     rest             1
# 4            4   2  low fat     92  15 min     rest             1
# ..         ...  ..      ...    ...     ...      ...           ...
# 85          85  29   no fat    135  15 min  running             0
# 86          86  29   no fat    130  30 min  running             0
# 87          87  30   no fat     99   1 min  running             0
# 88          88  30   no fat    111  15 min  running             0
# 89          89  30   no fat    150  30 min  running             0
#
#     time_encoded
# 0              0
# 1              1
# 2              2
# 3              0
# 4              1
# ..           ...
# 85             1
# 86             2
# 87             0
# 88             1
# 89             2
#
# [90 rows x 8 columns]

# %% [markdown]
# Betrachte die Werte von `time_encoded`: Bei Variante 1 stand da 1, 15 oder 30, jetzt steht da 0, 1 oder 2. Es ist unterscheidbar, aber die Variante 1 lässt präzisere Werte erscheinen.

# %% [markdown]
# ### Variante 3: One-hot encoding
#
# Diese Variante erstellt eine neue Spalte pro möglichen Weg.

# %%
df_ex_onehot = pd.get_dummies(df_ex, columns=['diet', 'time'])
df_ex_onehot
# Out:
#     Unnamed: 0  id  pulse     kind  diet_no fat  diet_low fat  time_1 min  \
# 0            0   1     85     rest            0             1           1
# 1            1   1     85     rest            0             1           0
# 2            2   1     88     rest            0             1           0
# 3            3   2     90     rest            0             1           1
# 4            4   2     92     rest            0             1           0
# ..         ...  ..    ...      ...          ...           ...         ...
# 85          85  29    135  running            1             0           0
# 86          86  29    130  running            1             0           0
# 87          87  30     99  running            1             0           1
# 88          88  30    111  running            1             0           0
# 89          89  30    150  running            1             0           0
#
#     time_15 min  time_30 min
# 0             0            0
# 1             1            0
# 2             0            1
# 3             0            0
# 4             1            0
# ..          ...          ...
# 85            1            0
# 86            0            1
# 87            0            0
# 88            1            0
# 89            0            1
#
# [90 rows x 9 columns]

# %%
import pandas as pd
import seaborn as sns

df_ex = sns.load_dataset('exercise')
df_ex.head(10)

df_ex['diet'].value_counts()

df_ex['time'].value_counts()

df_ex['kind'].value_counts()

df_ex_replace = df_ex.replace({
    "diet": {
        "no fat": 0,
        "low fat": 1
    },
    "time": {
        "1 min": 1,
        "15 min": 15,
        "30 min": 30
    }
})
df_ex_replace

df_ex_cat = df_ex.copy()
df_ex_cat['diet'] = df_ex_cat['diet'].astype('category')
df_ex_cat['time'] = df_ex_cat['time'].astype('category')
df_ex_cat[['diet', 'time']].dtypes

df_ex_cat['diet_encoded'] = df_ex_cat['diet'].cat.codes
df_ex_cat['time_encoded'] = df_ex_cat['time'].cat.codes
df_ex_cat

df_ex_onehot = pd.get_dummies(df_ex, columns=['diet', 'time'])
df_ex_onehot
# Out:
#     Unnamed: 0  id  pulse     kind  diet_no fat  diet_low fat  time_1 min  \
# 0            0   1     85     rest        False          True        True
# 1            1   1     85     rest        False          True       False
# 2            2   1     88     rest        False          True       False
# 3            3   2     90     rest        False          True        True
# 4            4   2     92     rest        False          True       False
# ..         ...  ..    ...      ...          ...           ...         ...
# 85          85  29    135  running         True         False       False
# 86          86  29    130  running         True         False       False
# 87          87  30     99  running         True         False        True
# 88          88  30    111  running         True         False       False
# 89          89  30    150  running         True         False       False
#
#     time_15 min  time_30 min
# 0         False        False
# 1          True        False
# 2         False         True
# 3         False        False
# 4          True        False
# ..          ...          ...
# 85         True        False
# 86        False         True
# 87        False        False
# 88         True        False
# 89        False         True
#
# [90 rows x 9 columns]
